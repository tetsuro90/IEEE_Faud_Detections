# %%
# General imports
import sys
sys.path.append('/tmp/working/IEEE_Fraud_Detection/')

import numpy as np
import pandas as pd
import os, sys, gc, warnings, random, datetime

import seaborn
import matplotlib.pyplot as plt

from functions.functions import load_datasets

warnings.filterwarnings('ignore')

# %%
# Set start date
START_DATE = datetime.datetime.strptime('2017-11-30', '%Y-%m-%d')

# %%
# Data Load
train, test = load_datasets(['transaction_identity_merged', 'transaction_d_t'])

# %%
i_cols = ['D'+str(i+1) for i in range(15)]
train[i_cols].head()
# Out:
#       D1     D2    D3    D4   D5  D6  D7  ...  D9   D10    D11  D12  D13  D14    D15
# 0   14.0    NaN  13.0   NaN  NaN NaN NaN  ... NaN  13.0   13.0  NaN  NaN  NaN    0.0
# 1    0.0    NaN   NaN   0.0  NaN NaN NaN  ... NaN   0.0    NaN  NaN  NaN  NaN    0.0
# 2    0.0    NaN   NaN   0.0  NaN NaN NaN  ... NaN   0.0  315.0  NaN  NaN  NaN  315.0
# 3  112.0  112.0   0.0  94.0  0.0 NaN NaN  ... NaN  84.0    NaN  NaN  NaN  NaN  111.0
# 4    0.0    NaN   NaN   NaN  NaN NaN NaN  ... NaN   NaN    NaN  NaN  NaN  NaN    NaN
#
# [5 rows x 15 columns]

# %%
train.head()
# Out:
#    TransactionID  isFraud  TransactionDT  ...  DT_M_total DT_W_total  DT_D_total
# 0        2987000        0          86400  ...      137321      12093        5122
# 1        2987001        0          86401  ...      137321      12093        5122
# 2        2987002        0          86469  ...      137321      12093        5122
# 3        2987003        0          86499  ...      137321      12093        5122
# 4        2987004        0          86506  ...      137321      12093        5122
#
# [5 rows x 446 columns]

# %%
temp_df.set_index(periods).head()
# Out:
#       TransactionDT     D1     D2    D3    D4  ...    D11  D12  D13  D14    D15
# DT_D                                           ...
# 335           86400   14.0    NaN  13.0   NaN  ...   13.0  NaN  NaN  NaN    0.0
# 335           86401    0.0    NaN   NaN   0.0  ...    NaN  NaN  NaN  NaN    0.0
# 335           86469    0.0    NaN   NaN   0.0  ...  315.0  NaN  NaN  NaN  315.0
# 335           86499  112.0  112.0   0.0  94.0  ...    NaN  NaN  NaN  NaN  111.0
# 335           86506    0.0    NaN   NaN   NaN  ...    NaN  NaN  NaN  NaN    NaN
#
# [5 rows x 16 columns]

# %%
# plot D columns
periods = ['DT_D']
temp_df = pd.concat([train[['TransactionDT'] + i_cols + periods], test[['TransactionDT'] + i_cols + periods]])

for col in i_cols:
    temp_df.set_index(periods)[col].plot(style='.', title=col, figsize=(15, 3))
    plt.show()

# %%
df_train, df_test = load_datasets(['d_columns_engineering'])
df_train.head()
# Out:
#    uid_D1_mean  uid_D1_std  ...  D15_DT_M_min_max  D15_DT_M_std_score
# 0     2.333333    5.715476  ...          0.000000           -0.807884
# 1    95.801515  178.811695  ...          0.000000           -0.807884
# 2    51.803602   93.084211  ...          0.433884            0.937510
# 3   150.329065  196.226675  ...          0.152893           -0.192841
# 4    95.533333  178.957852  ...               NaN                 NaN
#
# [5 rows x 275 columns]

# %%
train = pd.read_pickle('/tmp/working/IEEE_Fraud_Detection/train_2.pkl')
test = pd.read_pickle('/tmp/working/IEEE_Fraud_Detection/test_2.pkl')

# %%
train.iloc[0,473]
# Out:
# 0.0023428348

# %%
test.iloc[0, 473]
# Out:
# 0.0022291574
